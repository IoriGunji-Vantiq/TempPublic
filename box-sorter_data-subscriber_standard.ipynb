# %% [markdown]
# <a href="https://colab.research.google.com/github/IoriGunji-Vantiq/TempPublic/blob/master/box-sorter_data-subscriber_standard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MQTT Subscriber Sample
# MQTTブローカーからメッセージの受信を行うサンプルスクリプトになります。
#
# ## 設定方法
# 利用する際は事前にいくつか設定が必要になります。
# また、事前に Google へのログインが必要になります。
#
# ### MQTTブローカーの設定
# `# MQTTブローカー設定` に必要な情報を入力します。
# - `broker`：ホスト名を入力します。
# - `port`：MQTTのポート番号を入力します。
# - `topic`：トピック名を入力します。
# - `client_id`：クライアントIDは、特段の事情がない限り変更不要です。
# - `username`：ユーザー名を設定しない場合は、設定不要です。
# - `password`：パスワードを設定しない場合は、設定不要です。
#
# ## メッセージの受信方法
# 1. 初回実行時または実行時にエラーが出る場合は、モジュールのインストールを行います。
#    1. `# モジュールのインストール` の左側の実行ボタンをクリックします。
# 1. モジュールのインポートを行います。
#    1. `# モジュールインポート` の左側の実行ボタンをクリックします。
# 1. 設定情報を反映させます。
#    1. `# MQTTブローカー設定` の左側の実行ボタンをクリックします。
# 1. メッセージの受信を行います。
#    1. `# MQTT Subscriber 本体` の左側の実行ボタンをクリックします。
#
# ## メッセージ受信の停止方法
# 1. `# MQTT Subscriber 本体` の左側の停止ボタンをクリックします。

# %%
# モジュールのインストール
# !pip install paho-mqtt

# %%
# モジュールインポート
import random
from datetime import datetime as dt
from paho.mqtt import client as mqtt_client

# %%
# MQTTブローカー設定
mqtt_config = {
    'broker': 'broker.hivemq.com'
    , 'port': 1883
    , 'topic': '/center/senter_name'
    , 'client_id': f'python-mqtt-{random.randint(0, 100)}'
    , 'username': ''
    , 'password': ''
}

# %%
# MQTT Subscriber 本体
def connect_mqtt() -> mqtt_client:
    def on_connect(client, userdata, flags, rc):
        if rc == 0:
            print("Connected to MQTT Broker!\n")
        else:
            print("Failed to connect, return code %d\n", rc)

    client = mqtt_client.Client(mqtt_config['client_id'])
    client.username_pw_set(mqtt_config['username'], mqtt_config['password'])
    client.on_connect = on_connect
    client.connect(mqtt_config['broker'], mqtt_config['port'])
    return client


def subscribe(client: mqtt_client):
    def on_message(client, userdata, msg):
        print(f"Topic: {msg.topic}")
        print(f"{msg.payload.decode()}")
        print(f"Subscribed Time: {dt.now()}")
        print()

    client.subscribe(mqtt_config['topic'])
    client.on_message = on_message


def run():
    client = connect_mqtt()
    subscribe(client)
    client.loop_forever()


if __name__ == '__main__':
    run()
# Out:
# Connected to MQTT Broker!
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:08:39","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:08:39.334125
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:08:39","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:08:39.449835
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:09","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:09:09.357742
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:09","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:09:09.501288
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:11","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:09:11.403669
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:11","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:09:11.495074
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:23","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:09:23.434682
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:23","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:09:23.512683
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:39","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:09:39.503648
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:39","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:09:39.536143
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:41","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:09:41.476208
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:41","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:09:41.529449
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:45","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:09:45.420092
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:45","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:09:45.531807
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:53","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:09:53.417780
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:53","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:09:53.541786
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:55","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:09:55.419050
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:09:55","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:09:55.651298
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:01","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:10:01.443734
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:01","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:10:01.549516
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:05","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:10:05.434862
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:05","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:10:05.556624
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:11","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:10:11.653273
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:11","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:10:11.665761
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:27","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:10:27.559741
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:27","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:10:27.583380
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:33","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:10:33.483806
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:33","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:10:33.591605
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:43","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:10:43.531418
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:43","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:10:43.604562
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:45","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:10:45.647700
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:45","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:10:45.647812
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:49","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:10:49.499499
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:49","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:10:49.618646
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:55","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:10:55.503304
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:10:55","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:10:55.622704
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:03","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:11:03.603063
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:03","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:11:03.632349
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:17","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:11:17.636779
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:17","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:11:17.647813
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:19","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:11:19.533955
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:19","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:11:19.657262
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:23","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:11:23.538193
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:23","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:11:23.655788
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:27","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:11:27.540939
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:27","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:11:27.659994
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:39","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:11:39.564463
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:39","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:11:39.683284
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:49","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:11:49.576289
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:49","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:11:49.732716
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:51","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:11:51.574105
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:51","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:11:51.695756
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:53","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:11:53.576152
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:53","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:11:53.699547
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:55","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:11:55.650459
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:11:55","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:11:55.700314
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:12:11","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:12:11.598410
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:12:11","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:12:11.728101
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:12:13","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:12:13.711330
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:12:13","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:12:13.727423
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:12:15","sorting_condition":{"_id":"64a67e76c32b6679159e9fc9","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:30.455Z","ars_createdBy":"e9cc46d7-77cc-4929-8261-40ddceb8b143"}}
# Subscribed Time: 2023-07-06 10:12:15.624134
#
# Topic: /center/ig/tokyo
# {"code":"14961234567890","name":"お茶 24本","time":"2023-07-06 10:12:15","sorting_condition":{"_id":"64a67e66a3eac6034a225e6e","center_id":1,"center_name":"東京物流センター","code":"14961234567890","ars_namespace":"BoxSorterStandard_test","ars_version":1,"ars_createdAt":"2023-07-06T08:42:14.808Z","ars_createdBy":"igunji@vantiq.com"}}
# Subscribed Time: 2023-07-06 10:12:15.723790
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-55c150bb54c3> in <cell line: 33>()
#      32
#      33 if __name__ == '__main__':
# ---> 34     run()
#
# <ipython-input-5-55c150bb54c3> in run()
#      28     client = connect_mqtt()
#      29     subscribe(client)
# ---> 30     client.loop_forever()
#      31
#      32
#
# /usr/local/lib/python3.10/dist-packages/paho/mqtt/client.py in loop_forever(self, timeout, max_packets, retry_first_connection)
#    1754             rc = MQTT_ERR_SUCCESS
#    1755             while rc == MQTT_ERR_SUCCESS:
# -> 1756                 rc = self._loop(timeout)
#    1757                 # We don't need to worry about locking here, because we've
#    1758                 # either called loop_forever() when in single threaded mode, or
#
# /usr/local/lib/python3.10/dist-packages/paho/mqtt/client.py in _loop(self, timeout)
#    1148
#    1149         try:
# -> 1150             socklist = select.select(rlist, wlist, [], timeout)
#    1151         except TypeError:
#    1152             # Socket isn't correct type, in likelihood connection is lost
#
# KeyboardInterrupt:
